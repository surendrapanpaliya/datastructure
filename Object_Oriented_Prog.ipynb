# %%
class StackClass:
    '''Stack Class Help document'''
    classvar = 100 # class variable
    def hellostack(self,name):
        '''Hello Stack Method'''
        self.name = name # object variable
        self.classvar = 10
        print("Class Variable",self.classvar)
        print("Hello Stack",name)

    def display(self):
        print("Name is",self.name)

Stackobject = StackClass()
Stackobject.hellostack('Stackname')
#help(Stackobject)

print(Stackobject.name)
Stackobject.display()

print(StackClass.classvar)
# Out:
# Hello Stack Stackname
# Stackname
# Name is Stackname
# 100

# %%
class StackClass:
    '''Stack Class Help document'''
    classvar = 100 # class variable
    def hellostack(self,name):
        '''Hello Stack Method'''
        self.name = name # object variable
        self.classvar = 10 # Not Recommended
        print("Class Variable",self.classvar)
        print("Hello Stack",name)

    def display(self):
        print("Name is",self.name)


Ob1 = StackClass()
print(Ob1.classvar)
Ob1.hellostack('Data Structure')
print(Ob1.classvar)
print(StackClass.classvar)
print(Ob1.classvar)
# Out:
# 100
# Class Variable 10
# Hello Stack Data Structure
# 10
# 100
# 10

# %%
class Stack:
    '''Stack Implementation'''
    def __init__(self):
        '''Initialisation of Stack class'''
        self.items = []

    def push(self,item):
        '''Push data item in stack'''
        self.items.append(item)
        return self.items

    def pop(self):
        '''Remove last item from stack'''
        self.items.pop()
        return self.items

    def first_item(self):
        '''Access first item from the stack'''
        return self.items[0]

    def last_items(self):
        '''Access last item from the stack'''
        return self.items[-1]

    def display(self):
        '''Display Stack items'''
        print(self.items)


stacks = Stack()

#print(type(stacks))

#dir(stacks)

# %%
stacks = Stack()
stacks.push('books')
stacks.display()
stacks.push('cbooks')
stacks.push('java books')
stacks.push('scala books')
stacks.push('spark books')
stacks.push('python book')
stacks.display()
stacks.pop()
stacks.display()
print(stacks.first_item())
print(stacks.last_items())
# Out:
# ['books']
# ['books', 'cbooks', 'java books', 'scala books', 'spark books', 'python book']
# ['books', 'cbooks', 'java books', 'scala books', 'spark books']
# books
# spark books

# %%
class Queue(Stack):
    '''Implementation of Queue'''
    def pop(self):
        '''pop first item'''
        self.items.pop(0)
        return self.items

queues = Queue()
queues.push('python')
queues.push('jython')
queues.push('Java')
queues.push('spark')
queues.display()
queues.pop()
queues.display()
queues.pop()
queues.display()
# Out:
# ['python', 'jython', 'Java', 'spark']
# ['jython', 'Java', 'spark']
# ['Java', 'spark']

# %%
from collections import deque
from typing import Any

# Create linklist datastructure using queue which allows to insert and remove item
# at given index position. It should allow to access item or element from any index position.

class LinkedList():
    def __init__(self):
        self.queue = deque()

    def insert(self, index, item):
        if index < 0 or index > len(self.queue):
            raise IndexError("Index out of range")
        self.queue.insert(index, item)

    def remove(self, index):
        if index < 0 or index >= len(self.queue):
            raise IndexError("Index out of range")
        return self.queue.pop(index)

    def access(self, index):
        if index < 0 or index >= len(self.queue):
            raise IndexError("Index out of range")
        return self.queue[index]

    def display(self):
        print(self.queue)

linklists = LinkedList()
linklists.insert(0,'book2')
linklists.insert(1,'book3')
linklists.display()
linklists.queue.appendleft('firstbook')
linklists.display()
linklists.queue.rotate()
linklists.display()
# Out:
# deque(['book2', 'book3'])
# deque(['firstbook', 'book2', 'book3'])
# deque(['book3', 'firstbook', 'book2'])

# %%
import collections
#dir(collections)

# %%
# Create Bank Application Menu which include following options to customers
# 1. Welcome Message to customer
# 2. Create Account
# 3. Deposit Amount
# 4. Withdraw Amount if balance < 1000 then it should raise exception
# 5. Check Account Balance
# 6. Exit Bank Menu

# %%
class Bank:
    '''Bank Information'''

class Customer(Bank):
    '''Customer Information'''

class SavingAccount(Customer):
    '''Saving Account of Customer'''
    def credit(self,amount):
        pass
    def withdraw(self,amount):
        pass
    def balance(self):
        pass

# %%
# %%writefile BankApp.Py
#
# class InsufficientBalanceException(Exception):
#     """Custom exception for insufficient balance during withdrawal."""
#     pass
#
# class Account:
#     def __init__(self, account_number, name, initial_deposit):
#         self.account_number = account_number
#         self.name = name
#         self.balance = initial_deposit
#
#     def deposit(self, amount):
#         self.balance += amount
#         print(f"Amount deposited: {amount}. New balance: {self.balance}")
#
#     def withdraw(self, amount):
#         if self.balance - amount < 1000:
#             raise InsufficientBalanceException(f"Cannot withdraw {amount}. Minimum balance of 1000 must be maintained.")
#         self.balance -= amount
#         print(f"Amount withdrawn: {amount}. New balance: {self.balance}")
#
#     def check_balance(self):
#         print(f"Account balance: {self.balance}")
#
# class Bank:
#     def __init__(self):
#         self.accounts = {}
#
#     def create_account(self):
#         account_number = input("Enter account number: ")
#         name = input("Enter account holder's name: ")
#         initial_deposit = float(input("Enter initial deposit: "))
#         if initial_deposit < 1000:
#             print("Initial deposit must be at least 1000.")
#             return
#         self.accounts[account_number] = Account(account_number, name, initial_deposit)
#         print(f"Account created successfully for {name} with account number {account_number}.")
#
#     def deposit_amount(self):
#         account_number = input("Enter account number: ")
#         if account_number not in self.accounts:
#             print("Account not found.")
#             return
#         amount = float(input("Enter amount to deposit: "))
#         self.accounts[account_number].deposit(amount)
#
#     def withdraw_amount(self):
#         account_number = input("Enter account number: ")
#         if account_number not in self.accounts:
#             print("Account not found.")
#             return
#         amount = float(input("Enter amount to withdraw: "))
#         try:
#             self.accounts[account_number].withdraw(amount)
#         except InsufficientBalanceException as e:
#             print(e)
#
#     def check_balance(self):
#         account_number = input("Enter account number: ")
#         if account_number not in self.accounts:
#             print("Account not found.")
#             return
#         self.accounts[account_number].check_balance()
#
#     def show_menu(self):
#         while True:
#             print("\n*** Bank Menu ***")
#             print("1. Welcome Message")
#             print("2. Create Account")
#             print("3. Deposit Amount")
#             print("4. Withdraw Amount")
#             print("5. Check Account Balance")
#             print("6. Exit")
#
#             choice = input("Enter your choice: ")
#             if choice == '1':
#                 print("Welcome to the Bank! How can we assist you today?")
#             elif choice == '2':
#                 self.create_account()
#             elif choice == '3':
#                 self.deposit_amount()
#             elif choice == '4':
#                 self.withdraw_amount()
#             elif choice == '5':
#                 self.check_balance()
#             elif choice == '6':
#                 print("Thank you for banking with us. Goodbye!")
#                 break
#             else:
#                 print("Invalid choice. Please try again.")
#
# # Run the Bank Application
# if __name__ == "__main__":
#     bank = Bank()
#     bank.show_menu()
# Out:
# Writing BankApp.Py

# %% [markdown]
# Implementing a Stack
#
#     A stack is a linear data structure that follows
#     the Last In First Out (LIFO) principle.

# %%
class Stack:
    def __init__(self):
        self.items = []

    def push(self, item):
        """Add an item to the top of the stack."""
        self.items.append(item)

    def pop(self):
        """Remove and return the top item of the stack."""
        if not self.is_empty():
            return self.items.pop()
        else:
            raise IndexError("Pop from an empty stack")

    def peek(self):
        """Return the top item of the stack without removing it."""
        if not self.is_empty():
            return self.items[-1]
        else:
            raise IndexError("Peek from an empty stack")

    def is_empty(self):
        """Check if the stack is empty."""
        return len(self.items) == 0

    def size(self):
        """Return the number of items in the stack."""
        return len(self.items)


stack1 = Stack()

stack1.push('item1')

stack1.push('item2')

stack1.push('item3')

print(stack1.peek())

print(stack1.size())  # Output: 3
# Out:
# item3
# 3

# %% [markdown]
# 'is_empty',
#  'items',
#  'peek',
#  'pop',
#  'push',
#  'size'

# %%
class Queue:
    def __init__(self):
        self.items = []

    def enqueue(self, item):
        """Add an item to the end of the queue."""
        self.items.append(item)

    def dequeue(self):
        """Remove and return the item from the front of the queue."""
        if not self.is_empty():
            return self.items.pop(0)
        else:
            raise IndexError("Dequeue from an empty queue")

    def peek(self):
        """Return the item at the front of the queue without removing it."""
        if not self.is_empty():
            return self.items[0]
        else:
            raise IndexError("Peek from an empty queue")

    def is_empty(self):
        """Check if the queue is empty."""
        return len(self.items) == 0

    def size(self):
        """Return the number of items in the queue."""
        return len(self.items)

# Create an object of Queue
queue = Queue()

# Access methods
queue.enqueue(10)
queue.enqueue(20)
queue.enqueue(30)

print(queue.peek())  # Output: 10
print(queue.size())  # Output: 3

print(queue.dequeue())  # Output: 10
print(queue.size())  # Output: 2
# Out:
# 10
# 3
# 10
# 2

# %%
import numpy as np

class SimpleLinearRegression:
    def __init__(self):
        self.slope = 0
        self.intercept = 0

    def fit(self, X, y):
        """Fit the linear model to the data."""
        X = np.array(X)
        y = np.array(y)
        x_mean = np.mean(X)
        y_mean = np.mean(y)
        self.slope = np.sum((X - x_mean) * (y - y_mean)) / np.sum((X - x_mean) ** 2)
        self.intercept = y_mean - self.slope * x_mean

    def predict(self, X):
        """Predict using the linear model."""
        return np.array(X) * self.slope + self.intercept

    def coefficients(self):
        """Return the slope and intercept of the model."""
        return self.slope, self.intercept

# Create an object of SimpleLinearRegression
model = SimpleLinearRegression()

# Example data
X_train = [1, 2, 3]
y_train = [2, 4, 6]

# Access methods
model.fit(X_train, y_train)
print("Coefficients:", model.coefficients())  # Output: Coefficients: (2.0, 0.0)

X_test = [4, 5]
print("Predictions:", model.predict(X_test))  # Output: Predictions: [ 8. 10.]
# Out:
# Coefficients: (2.0, 0.0)
# Predictions: [ 8. 10.]

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None
        self.prev = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def append(self, value):
        new_node = Node(value)
        if self.tail:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
        else:
            self.head = new_node
            self.tail = new_node

    def display_forward(self):
        nodes = []
        current = self.head
        while current:
            nodes.append(current.value)
            current = current.next
        return nodes

    def display_backward(self):
        nodes = []
        current = self.tail
        while current:
            nodes.append(current.value)
            current = current.prev
        return nodes

# Create an object of DoublyLinkedList
dll = DoublyLinkedList()

# Access methods
dll.append(10)
dll.append(20)
dll.append(30)

print("Forward:", dll.display_forward())  # Output: Forward: [10, 20, 30]
print("Backward:", dll.display_backward())  # Output: Backward: [30, 20, 10]
# Out:
# Forward: [10, 20, 30]
# Backward: [30, 20, 10]

# %%
class HashTable:
    def __init__(self, size=10):
        self.size = size
        self.table = [[] for _ in range(size)]

    def _hash_function(self, key):
        """Hash function to compute index."""
        return hash(key) % self.size

    def insert(self, key, value):
        """Insert key-value pair into the hash table."""
        index = self._hash_function(key)
        # Check if key already exists and update it
        for i, kv in enumerate(self.table[index]):
            if kv[0] == key:
                self.table[index][i] = (key, value)
                return
        # Otherwise, add a new key-value pair
        self.table[index].append((key, value))

    def get(self, key):
        """Retrieve value by key."""
        index = self._hash_function(key)
        for kv in self.table[index]:
            if kv[0] == key:
                return kv[1]
        raise KeyError(f"Key {key} not found")

    def delete(self, key):
        """Remove key-value pair by key."""
        index = self._hash_function(key)
        for i, kv in enumerate(self.table[index]):
            if kv[0] == key:
                del self.table[index][i]
                return
        raise KeyError(f"Key {key} not found")

# Create an object of HashTable
hash_table = HashTable()

# Access methods
hash_table.insert("name", "Alice")
hash_table.insert("age", 30)

print("Name:", hash_table.get("name"))  # Output: Name: Alice
print("Age:", hash_table.get("age"))  # Output: Age: 30

hash_table.delete("name")
try:
    print(hash_table.get("name"))  # This will raise KeyError
except KeyError as e:
    print(e)  # Output: Key name not found
# Out:
# Name: Alice
# Age: 30
# 'Key name not found'

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    @classmethod
    def from_list(cls, values):
        """Create a LinkedList from a list of values."""
        linked_list = cls()
        if not values:
            return linked_list
        linked_list.head = Node(values[0])
        current = linked_list.head
        for value in values[1:]:
            current.next = Node(value)
            current = current.next
        return linked_list

    def display(self):
        """Display the linked list."""
        values = []
        current = self.head
        while current:
            values.append(current.value)
            current = current.next
        return values

# Use the factory method to create a LinkedList
values = [1, 2, 3, 4, 5]
linked_list = LinkedList.from_list(values)

# Access instance methods
print("Linked List:", linked_list.display())  # Output: Linked List: [1, 2, 3, 4, 5]
# Out:
# Linked List: [1, 2, 3, 4, 5]

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

class BinarySearchTree:
    def __init__(self):
        self.root = None

    def insert(self, value):
        if self.root is None:
            self.root = Node(value)
        else:
            self._insert(self.root, value)

    def _insert(self, node, value):
        if value < node.value:
            if node.left is None:
                node.left = Node(value)
            else:
                self._insert(node.left, value)
        else:
            if node.right is None:
                node.right = Node(value)
            else:
                self._insert(node.right, value)

    def find(self, value):
        return self._find(self.root, value)

    def _find(self, node, value):
        if node is None:
            return False
        if value == node.value:
            return True
        elif value < node.value:
            return self._find(node.left, value)
        else:
            return self._find(node.right, value)

    def in_order_traversal(self):
        return self._in_order_traversal(self.root, [])

    def _in_order_traversal(self, node, values):
        if node:
            self._in_order_traversal(node.left, values)
            values.append(node.value)
            self._in_order_traversal(node.right, values)
        return values

    def pre_order_traversal(self):
        return self._pre_order_traversal(self.root, [])

    def _pre_order_traversal(self, node, values):
        if node:
            values.append(node.value)
            self._pre_order_traversal(node.left, values)
            self._pre_order_traversal(node.right, values)
        return values

    def post_order_traversal(self):
        return self._post_order_traversal(self.root, [])

    def _post_order_traversal(self, node, values):
        if node:
            self._post_order_traversal(node.left, values)
            self._post_order_traversal(node.right, values)
            values.append(node.value)
        return values

# Create a BinarySearchTree object and test its methods
bst = BinarySearchTree()
bst.insert(5)
bst.insert(3)
bst.insert(7)
print("In-order traversal:", bst.in_order_traversal())  # Output: [3, 5, 7]
print("Find 7:", bst.find(7))  # Output: True
print("Find 10:", bst.find(10))  # Output: False
# Out:
# In-order traversal: [3, 5, 7]
# Find 7: True
# Find 10: False

# %%
class Graph:
    def __init__(self):
        self.graph = {}

    def add_vertex(self, vertex):
        if vertex not in self.graph:
            self.graph[vertex] = []

    def add_edge(self, vertex1, vertex2):
        if vertex1 in self.graph and vertex2 in self.graph:
            self.graph[vertex1].append(vertex2)
            self.graph[vertex2].append(vertex1)
        else:
            raise ValueError("Both vertices must be in the graph")

    def get_neighbors(self, vertex):
        return self.graph.get(vertex, [])

    def display(self):
        for vertex, edges in self.graph.items():
            print(f"{vertex}: {edges}")

# Create a Graph object and test its methods
g = Graph()
g.add_vertex('A')
g.add_vertex('B')
g.add_vertex('C')
g.add_edge('A', 'B')
g.add_edge('A', 'C')
g.display()
print("Neighbors of 'A':", g.get_neighbors('A'))  # Output: Neighbors of 'A': ['B', 'C']
# Out:
# A: ['B', 'C']
# B: ['A']
# C: ['A']
# Neighbors of 'A': ['B', 'C']
